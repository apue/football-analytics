# %% [markdown]
# # <lesson-id> <title>
#
# **Question:** <bounded football question>
#
# **Pre-analysis prediction:** <record before calculating>
#
# This notebook orchestrates the analysis. Reusable logic belongs in `src/`.

# %%
from football_analytics import get_open_data_root, get_project_root

PROJECT_ROOT = get_project_root()
OPEN_DATA_ROOT = get_open_data_root(PROJECT_ROOT)
PROJECT_ROOT, OPEN_DATA_ROOT

# %% [markdown]
# ## Data scope and checks
#
# Record the upstream commit, sample boundaries, exclusions, missing values, and unit of analysis before calculating metrics.

# %% [markdown]
# ## Analysis
#
# For every output, explain how to read it, what it supports, and what it cannot establish.

# %% [markdown]
# ## Interpretation and next check
#
# Separate data fact, metric result, football interpretation, and unverified hypothesis.
